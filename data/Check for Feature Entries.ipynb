# %%
import pickle

with open('dicts.pkl', 'rb') as handle:
    unserialized_data = pickle.load(handle)

# %%
unserialized_data.keys()
# Out:
# dict_keys(['food', 'chem', 'sci_name'])

# %%
unserialized_data['food']
# Out:
# ['angelica',
#  'savoy cabbage',
#  'silver linden',
#  'kiwi',
#  'allium (onion)',
#  'garden onion',
#  'leek',
#  'garlic',
#  'chives',
#  'lemon verbena',
#  'cashew nut',
#  'pineapple',
#  'dill',
#  'custard apple',
#  'wild celery',
#  'peanut',
#  'burdock',
#  'horseradish',
#  'tarragon',
#  'mugwort',
#  'asparagus',
#  'oat',
#  'star fruit',
#  'brazil nut',
#  'common beet',
#  'borage',
#  'chinese mustard',
#  'swede',
#  'rape',
#  'common cabbage',
#  'cauliflower',
#  'brussel sprouts',
#  'kohlrabi',
#  'broccoli',
#  'chinese cabbage',
#  'turnip',
#  'pigeon pea',
#  'tea',
#  'capers',
#  'pepper (c. annuum)',
#  'papaya',
#  'safflower',
#  'caraway',
#  'pecan nut',
#  'chestnut',
#  'roman camomile',
#  'chickpea',
#  'endive',
#  'chicory',
#  'chinese cinnamon',
#  'ceylon cinnamon',
#  'watermelon',
#  'lime',
#  'lemon',
#  'pummelo',
#  'mandarin orange (clementine, tangerine)',
#  'sweet orange',
#  'coffee',
#  'arabica coffee',
# ...
